# %%
print("Hello world")

# %%
initial_count =100
final_count = initial_count + 0
print(f"1. count after adding zero: {final_count}")

# %%
active_students =1620
dropouts = -20
active_students = active_students + dropouts
print(f"1. active students after droupouts: {active_students}")

# %%
completed_projects =5
completed_projects = completed_projects +1
print(f"1. completed projects incremented: {completed_projects}")

# %%
duration1 =8
duration2 =12
total_duration = duration1 + duration2
print(f"1. total duration in weeks: {total_duration}")

# %% [markdown]
# ## This is my new testing programs

# %%
a=5+5

# %%
a

# %%
print(input("The first number is:"))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_14435/2076803030.py in <cell line: 0>()
# ----> 1 print(input("The first number is:"))
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
# ...

# %%
ds_modules = 13
de_modules = 55
total_modules = ds_modules + de_modules
print(f"The total modules of DS and DE are: '{total_modules}'")

# %%
batch_size_1 =50
batch_size_2 =45
combined_batch_size = batch_size_1 + batch_size_2
print(f"1. combined size of two batches :{combined_batch_size}")

# %%
new_student_batch1 =120
total_students =1500
total_students =total_students + new_student_batch1
print(f"1. total students after batch 1: {total_students}")

# %%
aec_modules =5
emw_Modules =5
total_modules = aec_modules + emw_Modules
print(f"1. total  modules in aec& emw : {total_modules}")

# %%
batch_size1 =50
batch_size2 =45
combined_batch_size = batch_size1 + batch_size2
print(f"1. combined of two batches: {combined_batch_size}")

# %%
subject_1 =60
subject_2 =80
total_marks = subject_1 + subject_2
print(f"1. combined marks of two subjects: {total_marks}")

# %%
ds_instructors =3
de_instructors =4
total_instructors = ds_instructors + de_instructors
print(f"1. total instructors: {total_instructors}")

# %%
assignments_part1 = 25
assignments_part2 = 30
total_assignments = assignments_part1 + assignments_part2
print(f"1. Total assignments: {total_assignments}")

# %%
student_change = 50 + (-10) + 30
print(f"1. net student change: {student_change}")

# %%
pizza_price1 = 40
burger_price2 =20
total_bill = pizza_price1 + burger_price2
print(f"1. total bill: {total_bill} dollar")

# %%
batch_capacity = 60
enrolled =55
remaining_seats = batch_capacity - enrolled
print(f"1. remaining seats:{remaining_seats}")

# %%
intial_students = 1500
final_students = 1485
dropouts = intial_students - final_students
print(f"1.  no of dropouts: {dropouts}")

# %%
ds_modules = 15
de_modules =18
module_diffrence = de_modules - ds_modules
print(f"1. diffrence of modules: {module_diffrence}")

# %%
revenue = 5000
revenue_after_discout = revenue - 0
print(f"1. revenue after zero discount: {revenue_after_discout}")

# %%
costs = 6000
profit = revenue - costs
print(f"1. profit : {profit}")

# %%
live_sessions_left =10
live_sessions_left = live_sessions_left -1
print(f"1. live sessions left after one:{live_sessions_left}")

# %%
current_year = 2024
launch_year = 2020
years_active = current_year - launch_year
print(f"1.  years active: {years_active}")

# %%
intial_score =80
score_penalty = -10
final_score = intial_score - score_penalty
print(f"1. score after penalty: {final_score}")

# %%
total_days = 90
days_passed = 30
days_remaining = total_days - days_passed
print(f"1. days remaining: {days_remaining}")

# %%
average_rating = 4.8356
rounded_rating_1dp = round(average_rating, 1)
print(f"1. avrage rating rounded to 1dp: {rounded_rating_1dp}")

# %%
rounded_rating_int = round(average_rating)
print(f"1. average rating to nearest int: {rounded_rating_int}")

# %%
completion_rate = 46.66666
rounded_rate_2dp = round(completion_rate, 2)
print(f"1. completion rate rounded to 2dp: {rounded_rate_2dp}")

# %%
rounded_rate =3.14159
rounded_rate_2dp = round(rounded_rate, 2)
print(f"1. rounded rate to 2dp:{rounded_rate_2dp}")

# %%
rounded_rate = 5.5
rounded_rate = round(rounded_rate)
print(f"1. rounded rate: {rounded_rate}")

# %%
round_rate = 3.14159
rounded_rate_3dp = round(round_rate,3)
print(f"1. rounded rate to 3 dp: {rounded_rate_3dp}")

# %%
rounded_rate = 1234
rounded_value = round(rounded_rate, -1)
print(f"1. rounded rate to nearest 10: { rounded_value} ")

# %%
rounded_rate = 5678
rounded_value_hundred = round(rounded_rate, -2)
print(f"1. rounded rate to nearest 100: {rounded_value_hundred}")

# %%
average_rating = 4.8
print(f"1. is {average_rating} an intiger? {average_rating.is_integer()}")

# %%
total_students_str = "1500"
total_students_int = int(total_students_str)
print(f"1. total students from string: {total_students_int}")

# %%
neg_float_str = "-10.5"
neg_int = int(float(neg_float_str))
print(f"1. intiger from string: {neg_int}")

# %%
is_full_int =int(False)
print(f"1. intiger value of false: {is_full_int}")

# %%
positive_float = 99.99
positive_int = int(positive_float)
print(f"1. intiger value from float: {positive_int}")

# %%
negative_float = -0.1
negative_int = int(negative_float)
print(f"1. intiger value from float: {negative_int}")

# %%
binary_string = "1101"
decimal_value = int(binary_string, 2)
print(f"1. intiger value from binary: {decimal_value}")

# %%
hex_str = "ff"
decimal_value_hex = int(hex_str, 16)
print(f"1. intiger from hex: {decimal_value_hex}")

# %%
ratio = (0.5).as_integer_ratio()
print(f"1. ratio of 0.5: {ratio}")

# %%
average_rating = 4.8
ratio = average_rating.as_integer_ratio()
print(f"1. ratio for average rating: {ratio} ")
ratio_simple = (4.75).as_integer_ratio()
print(f"1. ratio for simple rating: {ratio_simple}")

# %%
total_students = 1500
students_float = float(total_students)
print(f"1. total students as float: {students_float}")

# %%
zero_float = float(0)
print(f"1. intiger 0 as a float: {zero_float} ")

# %%
average_rating_string = "4.8"
average_rating_float = float(average_rating_string)
print(f"1. average rating from string: {average_rating_float}")

# %%
int_str= "100"
int_str_float = float(int_str)
print(f"1. intiger stringas as a float:{int_str_float}")

# %%
sci_str = "1.5e3"
sci_float = float(sci_str)
print(f"1. float from sci str: {sci_float}")

# %%
true_float = float(True)
print(f"1. float value of true: {true_float}")

# %%
false_float = float(False)
print(f"1. float value of False: {false_float}")

# %%
neg_int_str = "-50"
neg_int_float = float(neg_int_str)
print(f"1. float from '-50': {neg_int_float}")

# %%
growth_projection = complex(10, 3)
adjustment_factor = complex(1, -0.5)
result = growth_projection * adjustment_factor
print(f"1. {growth_projection} * {adjustment_factor} = {result}")

# %%
scale_factor = 2
scaled_projection = growth_projection * scale_factor
print(f"1.result of scale factor: {scaled_projection}")

# %%
imag_factor = 1j
rotated_projection = growth_projection * imag_factor
print(f"1, reasult of imag factor: {rotated_projection}")

# %%
squaring_projection = growth_projection ** 2
print(f"1. result of squaring projection: {squaring_projection}")

# %%
zero_complex = complex(0, 0)
result = growth_projection * zero_complex
print(f"1. {growth_projection} * {zero_complex} = {result}")

# %%
conjugate = growth_projection.conjugate()
result = growth_projection * conjugate
print(f"1. {growth_projection} * {conjugate} = {result}")

# %%
c1 = complex(-2, 1)
c2 = complex(1,-3)
result = c1 * c2
print(f"1. c1 * c2 = {result}")

# %%
c1 = 1+1j
c2 = 1+1j
result = c1 * c2
print(f"1. {c1} * {c2}  = {result}")

# %%
identity = complex(1,0)
result= growth_projection * identity
print(f"1. growth_projection * identitiy = {result}")

# %%
z1 = 2 + 3j
z2 = 4 - 5j
result = z1 * z2
print(f"1. z1 * z2 = {result}")

# %%
z1 = 2 + 3j
z2 = 4 - 5j
result = z1 + z2
print(f"1. z1 + z2 = {result}")

# %%
z1 = 2 + 3j
z2 = 4- 5j
result = z1 / z2
print(f"1. z1 /z2 = {result}")

# %%
growth_projection = 10+ 3j
real_part = growth_projection.real
print(f"1. real part of growth projection: {real_part}")

# %%
imag_num = 5j
real_part = imag_num.real
print(f"1. real part of imag num: {real_part}")

# %%
real_num = 1500
real_part = real_num.real
print(f"1. real part of real num: {real_part}")

# %%
neg_real_component = -5+2j
real_part = neg_real_component.real
print(f"1. real part of the componene: {real_part}")

# %%
result = growth_projection.real * 2
print(f"1. real part of growth projecdtion: {result}")

# %%
float_complex = complex(4.8, -1.5)
real_part = float_complex.real
print(f"1. real part of float complex: {real_part}")

# %%
c1 = 1+2j
c2 = 3+4j
sum_c = c1+ c2
rel_part = sum_c.real
print(f"1. real part of sum_c: {real_part}")

# %%
conjugate = growth_projection.conjugate()
real_part = conjugate.real
print(f"1. real pert of conjugate: {real_part}")

# %%
c= 7+0j
real_part = c.real
print(f" real part of c: {real_part}")

# %%
growth_projection = 10+3j
conj = growth_projection.conjugate()
print(f"1. conjugate of growth projection: {conj}")

# %%
imag_num = 5j
conj = imag_num.conjugate()
print(f"1. conjugate of image num: {conj}")

# %%
total_students = 1500 + 0j

real_num = complex(total_students, 0)  # imaginary part defaults to 0
conjugate_num = real_num.conjugate()

print("1. Conjugate of real number:", conjugate_num)

# %%
neg_imag_complex = 4-7j
conj = neg_imag_complex.conjugate()
print(f"1. the conjugate of neg img complex: {conj}")

# %%
zero_complex = 0j
conj = zero_complex.conjugate()
print(f"1. conjugate of {zero_complex}: {conj}")

# %%
c1 = 1+2j
c2 = 3-4j
sum_conj = (c1+c2).conjugate()
ind_conj_sum = c1.conjugate() + c2.conjugate()
print(f"1. conjugate of sum: {sum_conj}, sum of conjugates: {ind_conj_sum}")

# %%
c1 = 1+2j
c2 = 3-4j
prod_conj = (c1*c2).conjugate()
ind_conj_prod = c1.conjugate() * c2.conjugate()
print(f"1. conjugate of product: {prod_conj}, product of conjugates: {ind_conj_prod}")

# %%
neg_real_coplex = -5+2j
conj = neg_real_coplex.conjugate()
print(f"1. conjugate of neg real complex: {conj}")

# %%
growth_projection = 10 + 3j
magnitude = abs(growth_projection)
print(f"1. magnitude abs value of growth projection: {magnitude:.4f}")

# %%
imag_num = 5j
magnitude = abs(imag_num)
print(f"1. magnitude abs value of imag num: {magnitude}")

# %%
real_num = complex(-1500, 0)
magnitude = abs(real_num)
print(f"1. magnitudem of real num: {magnitude}")

# %%
c = 3 + 4j
magnitude = abs(c)
print(f"1. absoulate value of c: {magnitude}")

# %%
zero_complex = 0j
magnitude = abs(zero_complex)
print(f"1. absoulate value of zero: {magnitude}")

# %%
z = 3 + 4j
magnitude = abs(z)
print(f"1. absolute value of z: {magnitude}")

# %%
z = -6 - 8j
magnitude = abs(z)
print(f"1. absoulate value of z: {magnitude}")

# %%
real = float(input("Enter real part: "))
imag = float(input("Enter imaginary part: "))

z = complex(real, imag)
print(f"1.Magnitude:", abs(z))

# %%
z1 = 3 + 4j
z2 = 5 + 12j
if abs(z1) >abs(z2):
  print(f"1. z1 is larger")
else:
  print(f"1. z1 is larger")

# %%
z1 = 2+3j
z2 = 5+7j
distance = abs(z1-z2)
print(f"1. distance between z1 and z2: {distance}")

# %%
z1 = 2+2j
z2 = 3+12j
compare = abs(z1) > abs(z2)
print(f"1. compare the absoulte value of z1 and z2: {compare}")

# %%
z1 = 1+2j
z2 = 4+6j
distance = abs(z1-z2)
print(f"1. distance between z1 and z2: {distance}")

# %%
c = complex(10, 3)
print(f"1. complex(10, 3): {c}")

# %%
c = complex(5000)
print(f"1. complex(5000): {c}")

# %%
c = complex(4.8)
print(f"1. complex(4.8): {c}")

# %%
institute = "edukron"
focus_area = "data science"
full_title = institute + ":" + focus_area
print(f"1. full title : {full_title}")

# %%
course_name = "azure devops "
welcome_message = "welcome to " + institute + "s" + course_name + "course"
print(f"1. welcome message: {welcome_message}")

# %%
separator = "=*+" * 10
print(f"1. separator: {separator}")

# %%
keyword = "ptyhon "
separator = keyword * 3
print(f"1. separator keyword: {separator}")

# %%
base_path = "/courses"
course_id = "DA101"
full_path = base_path + course_id
print(f"1. simple path: {full_path}")

# %%
student_name = "sharp"
username_suffix = "@gmail.com"
email = student_name + username_suffix
print(f"1. student email: {email}")

# %%
heading = "course mosules"
underline = "=" * len(heading)
print(f"1. heading:\n{heading}\n{underline}")

# %%
part1 = "learn "
part2 = "data engineering "
part3 = "now! "
call_to_action = part1 + part2 + part3
print(f"1.call to action: {call_to_action}")

# %%
empty_repeated = "" * 100
print(f"1. repeating my string: '{empty_repeated}'")

# %%
message = "ALERT! "
no_alerts = message * 0
print(f"1. repeating zero times: '{no_alerts}'")

# %%
institute = "impact"
course_slogan = "leran artificial intiligence"
tech_stack = "html and c++"
name_length = len(institute)
name_course = len(course_slogan)
name_tech = len(tech_stack)
print(f"1. length of institute: {name_length}")
print(f"1. length of the course: {name_course}")
print(f"1. length of the tech: {name_tech}")

# %%
empty_len = len("")
print(f"1. length of the empty string: {empty_len}")

# %%
spaces = "   "
spaces_len = len(spaces)
print(f"1' length of space: {spaces_len}")

# %%
password = "pass"
min_len = 8
password_len = len(password)
if len(password) < min_len:
  print(f"1. password '{password}'is too short (min {min_len} chars).")

# %%
complex_str = "batch #101!"
complex_len = len(complex_str)
print(f"1. length of combined string: {complex_len}")

# %%
institute = "imapact"
tech_stack = "html and ai"
combined = institute + tech_stack
combined_len = len(combined)
print(f"1. length of the combined string: {combined_len}")

# %%
char_str = "a"
char_len = len(char_str)
print(f"1. length of the single character: {char_len}")

# %%
institute = input("enter the institute: ")
tech_stack = input("enter the stack: ")
combined_length = len(institute + tech_stack)
print(f"1. combined lenth of the string: {combined_length}")

# %%
institute = "impact"
tech_stack = "ece and ai"
first_character = institute[0]
print(f"1. enter the first character of the institute: {first_character}")

# %%
institute = "bms"
tech_stack = "data science"
last_character = institute[-1]
print(f"1. last character of the institute: {last_character}")

# %%
institute = "bms"
tech_stack = "data science"
char_at_2 = institute[2]
print(f"1. character at index of 2: {char_at_2}")

# %%
institute = "impact college"
first_5 =institute[0:5]
print(f"1. first 5 characters: {first_5}")

# %%
tech_stack = "electronics and communication"
tech_stack = tech_stack[2:9]
print(f"1. extracting tech: {tech_stack}")

# %%
tech_stack = "data science"
middle = tech_stack[1:-1]
print(f"1. middle part of the tech: {middle}")

# %%
tech_stack = "data science"
every_second = tech_stack[::2]
print(f"1. every second part of the tech: {every_second}")

# %%
tech_stack = "scicence"
reversed_tech = tech_stack[::-1]
print(f"1. reversed value of tech: {reversed_tech}")

# %%
course_name = "artificial intilligence"
from_index_6 = course_name[6:]
print(f"1. course from index 6: {from_index_6}")

# %%
institute = "IMPACT"
lower_institute = institute.lower()
print(f"1. lower case of institute: {lower_institute}")

# %%
tech_course ="data science"
upper_tech = tech_course.upper()
print(f"1. upper case of tech: {upper_tech}")
# Out:
# 1. upper case of tech: DATA SCIENCE

# %%
tech_course = "data science"
user_input = "data science "
if user_input.lower() == tech_course.lower():
  print(f"1. user input matches tech course (case-insensitive).")

# %%
tech_course = "data science"
user_input = "data science "
if user_input.lower() == tech_course.lower():
  print(f"1. user input matches tech course (case-insensitive).")

# %%
student_name = "sharip"
upper_name = student_name.upper()
print(f"1. upper case of student name: {upper_name}")
# Out:
# 1. upper case of student name: SHARIP

# %%
student_name =input("enter the name of student:" )
upper_name = student_name.upper()
print(f"1. upper case of student name: {upper_name}")
# Out:
# enter the name of student:panchu
# 1. upper case of student name: PANCHU

# %%
course_name = "data engeineering"
words = course_name.split()
print(f"1. split the course name: {words}")
# Out:
# 1. split the course name: ['data', 'engeineering']

# %%
institute =" impact"
parts = institute.split('m')
print(f"1. split the institute: {parts}")
# Out:
# 1. split the institute: [' i', 'pact']

# %%
course_name = "data engenineering, science,sql"
split_limit = course_name.split(maxsplit=2)
print(f"1. spliting the course (maxspilt=2): {split_limit}")
# Out:
# 1. spliting the course (maxspilt=2): ['data', 'engenineering,', 'science,sql']

# %% [markdown]
# Institute
